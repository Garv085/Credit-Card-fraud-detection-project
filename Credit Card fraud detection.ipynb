# %%
import numpy as np
import pandas as pd 
import matplotlib as plt

# %%
#loading the dataset in our code
credit_data = pd.read_csv('creditcard.csv')

# %%
#getting the first 5 rows of the dataset
credit_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
credit_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
credit_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
#distribution of legit transaction and fraud transaction
credit_data['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
#The dataset here is highly unbalanced
# 0 --> legit transaction 1--> fraudalent transaction
credit_data.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.918649e-15  5.682686e-16 -8.761736e-15  2.811118e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552103e-15  2.040130e-15 -1.698953e-15 -1.893285e-16 -3.147640e-15
# ...

# %%
#analyzing the data by seperating the two transaction
legit = credit_data[credit_data.Class == 0]
fraud = credit_data[credit_data.Class == 1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (284315, 31)
# (492, 31)

# %%
#statistical measure of data
legit.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
#Compare the two transactions
credit_data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
#undersampling as the dataset is not balanced and fraud transactions are significantly less than the legit transactions
legit_sample = legit.sample(n=492)

# %%
legit_sample.shape
# Out:
# (492, 31)

# %%
#concatinate the small sample and fraud sample
new_credit = pd.concat([legit_sample , fraud] , axis=0)

# %%
new_credit.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 178376  123602.0 -0.020805  0.826488  0.496193 -0.705558  0.670715 -1.001812
# 204701  135403.0 -1.945443  1.585396 -1.046788 -0.980639 -0.108533 -0.701254
# 258595  158726.0  0.144976  0.913923 -0.795101 -0.877906  1.412962  0.120053
# 244534  152394.0  1.900032  0.047800 -2.722718  0.535881  0.961430 -1.165103
# 29084    35310.0  1.120689  0.069246  0.371138  1.485138 -0.432119 -0.648649
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 178376  1.381787 -0.603811  0.463275  ... -0.392043 -0.530619  0.008016
# 204701  0.503809  0.502853  0.984300  ... -0.446800 -0.839540  0.095529
# 258595  0.860490  0.128752 -0.221716  ... -0.342147 -0.886784 -0.001188
# 244534  0.930142 -0.524372 -0.054246  ...  0.100272  0.270304 -0.136660
# 29084   0.164699 -0.131184  0.380525  ... -0.109131 -0.243782 -0.123794
#
# ...

# %%
#Compare with the old dataset
new_credit.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      95025.928862 -0.028332 -0.017664  0.020671 -0.038678  0.051192
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.010505  0.042469 -0.092134  0.018853  ...  0.041015 -0.000510
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23      V24       V25       V26       V27       V28  \
# Class
# 0     -0.009456 -0.072439  0.04390 -0.010350  0.024385 -0.019571 -0.012586
# 1      0.014049 -0.040308 -0.10513  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       99.122215
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
new_credit['Class'].value_counts()
# Out:
# 0    492
# 1    492
# Name: Class, dtype: int64

# %%
X = new_credit.drop('Class' , axis=1)
y = new_credit['Class']

# %%
#splitting the dataset into training and testing dataset
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y , random_state=2)

# %%
print(X.shape)
print(X_train.shape)
print(X_test.shape)
# Out:
# (984, 30)
# (787, 30)
# (197, 30)

# %%
#Model training - Logistic Regression(Binary Classification)
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(X_train , y_train)
# Out:
# LogisticRegression()

# %%
#Model Evaluation 
from sklearn.metrics import accuracy_score

# %%
X_predictions = model.predict(X_train)

# %%
#accuracy on training data
train_accuracy = accuracy_score(X_predictions , y_train)
print('Accuracy on training data is: ', train_accuracy)
# Out:
# Accuracy on training data is:  0.9326556543837357

# %%
#accuracy on testing data
X_predictions_test = model.predict(X_test)
test_accuracy = accuracy_score(X_predictions_test , y_test)
print('Accuracy on training data is: ', test_accuracy)
# Out:
# Accuracy on training data is:  0.9187817258883249

# %%
#confusion matrix for testing data
from sklearn.metrics import confusion_matrix
train_matrix = confusion_matrix(X_predictions , y_train)
print( train_matrix)
# Out:
# [[373  33]
#  [ 20 361]]

# %%
#Model is working with an accuracy of more than 90% and  a confusion matrix with most TP and TN
